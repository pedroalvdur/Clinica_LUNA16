# %% [markdown]
# # Cancer Frequency

# %% [markdown]
# ### Libraries

# %%
import pandas as pd

# %% [markdown]
# ### Read Excel

# %%
df = pd.read_csv('E:/Prac_Clinicas/LIDC-IDRI/MetaData_1308.csv', index_col=0)
df.head()
# Out:
#                                                         Study UID  \
# Subject ID
# LIDC-IDRI-1001  1.3.6.1.4.1.14519.5.2.1.6279.6001.281499745765...
# LIDC-IDRI-0778  1.3.6.1.4.1.14519.5.2.1.6279.6001.174809695196...
# LIDC-IDRI-0813  1.3.6.1.4.1.14519.5.2.1.6279.6001.139110171863...
# LIDC-IDRI-0710  1.3.6.1.4.1.14519.5.2.1.6279.6001.116146223752...
# LIDC-IDRI-0410  1.3.6.1.4.1.14519.5.2.1.6279.6001.818775038273...
#
#                Study Description             Study Date  \
# Subject ID
# LIDC-IDRI-1001               NaN  2000-01-01 00:00:00.0
# LIDC-IDRI-0778             CHEST  2000-01-01 00:00:00.0
# LIDC-IDRI-0813               NaN  2000-01-01 00:00:00.0
# LIDC-IDRI-0710             CHEST  2000-01-01 00:00:00.0
# LIDC-IDRI-0410    CT LUNG SCREEN  2000-01-01 00:00:00.0
#
#                                                         Series ID  \
# Subject ID
# LIDC-IDRI-1001  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...
# ...

# %% [markdown]
# ### Massive CT

# %%
df.loc[df['Number of images'] >= 200]
# Out:
#                                                         Study UID  \
# Subject ID
# LIDC-IDRI-0778  1.3.6.1.4.1.14519.5.2.1.6279.6001.174809695196...
# LIDC-IDRI-0710  1.3.6.1.4.1.14519.5.2.1.6279.6001.116146223752...
# LIDC-IDRI-1002  1.3.6.1.4.1.14519.5.2.1.6279.6001.233360976397...
# LIDC-IDRI-0026  1.3.6.1.4.1.14519.5.2.1.6279.6001.279133908903...
# LIDC-IDRI-0830  1.3.6.1.4.1.14519.5.2.1.6279.6001.170453435914...
# ...                                                           ...
# LIDC-IDRI-0553  1.3.6.1.4.1.14519.5.2.1.6279.6001.330311286390...
# LIDC-IDRI-0542  1.3.6.1.4.1.14519.5.2.1.6279.6001.280963839031...
# LIDC-IDRI-0669  1.3.6.1.4.1.14519.5.2.1.6279.6001.886430358468...
# LIDC-IDRI-0473  1.3.6.1.4.1.14519.5.2.1.6279.6001.210105060472...
# LIDC-IDRI-0493  1.3.6.1.4.1.14519.5.2.1.6279.6001.333362756208...
#
#                Study Description             Study Date  \
# Subject ID
# LIDC-IDRI-0778             CHEST  2000-01-01 00:00:00.0
# ...

# %% [markdown]
# ### Small CT

# %%
df.loc[df['Number of images'] <= 5]
# Out:
#                                                         Study UID  \
# Subject ID
# LIDC-IDRI-0159  1.3.6.1.4.1.14519.5.2.1.6279.6001.150321127877...
# LIDC-IDRI-0252  1.3.6.1.4.1.14519.5.2.1.6279.6001.200320855621...
# LIDC-IDRI-0249  1.3.6.1.4.1.14519.5.2.1.6279.6001.119499039852...
# LIDC-IDRI-0245  1.3.6.1.4.1.14519.5.2.1.6279.6001.189903977601...
# LIDC-IDRI-0066  1.3.6.1.4.1.14519.5.2.1.6279.6001.293081776320...
# ...                                                           ...
# LIDC-IDRI-0041  1.3.6.1.4.1.14519.5.2.1.6279.6001.115366070341...
# LIDC-IDRI-0272  1.3.6.1.4.1.14519.5.2.1.6279.6001.332254403394...
# LIDC-IDRI-0145  1.3.6.1.4.1.14519.5.2.1.6279.6001.193227635862...
# LIDC-IDRI-0046  1.3.6.1.4.1.14519.5.2.1.6279.6001.189975013581...
# LIDC-IDRI-0121  1.3.6.1.4.1.14519.5.2.1.6279.6001.985098410443...
#
#                   Study Description             Study Date  \
# Subject ID
# LIDC-IDRI-0159  CHEST, PA & LATERAL  2000-01-01 00:00:00.0
# ...
