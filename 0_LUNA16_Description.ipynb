# %% [markdown]
# # LUNA16
#
# The task of this challenge is to automatically detect the location of nodules from volumetric CT images.
#
# The dataset is used for both training and testing dataset. To allow easier reproducibility, please use the given subsets for training the algorithm for 10-folds cross-validation.
#
# #### Data was collected for as many cases as possible and is associated at two levels:
#
#     -Diagnosis at the patient level (diagnosis is associated with the patient)
#     -Diagnosis at the nodule level (where possible)
#
#
# #### At each level, data was provided as to whether the nodule was:
#
#     -Unknown (no data is available)
#     -Benign or non-malignant disease
#     -A malignancy that is a primary lung cancer
#     -A metastatic lesion that is associated with an extra-thoracic primary malignancy
#
#
# #### For each lesion, there is also information provided as to how the diagnosis was established including options such as:
#
#     -unknown - not clear how diagnosis was established
#     -review of radiological images to show 2 years of stable nodule
#     -biopsy
#     -surgical resection
#     -progression or response

# %% [markdown]
# ## Likelyhood of nodule in certain area (the nodule detection track)
#
# Using raw CT scans, the goal is to identify locations of possible nodules, and to assign a probability for being a nodule to each location (754.975 candidates are expected).
#
# I think that after doing all the processing and thresholding to the images, there will be 754975 candidates of nodule.
#
# The goal is to assign a probability to each location of having a nodule candidate.
#
# #### Questions
# Relationship between LUNA16 and LIDC-IDRI. Maybe with the new images the are more candidates and more nodules to find out. Check Nodule_Count file.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Cancerous nodule (the false positive reduction track)
#
# Given a set of candidate locations, the goal is to assign a probability for being a nodule to each candidate location. Hence, one could see this as a classification task: nodule or not a nodule. Candidate locations will be provided in world coordinates. This set detects 1,162/1,186 nodules.
#
# I think the purpose of this challenge is to classify the 1186 nodules  image and determine whether they are a nodule or not. The first step would be to threshold the images to find all the candidates, with the location probability. The next step would be to classify all this candidates into nodule or not. With this approach maybe we can get better results than just inputting the original image or the shrinked one like the tutorial I saw.
#
# The goal is to find the most amount of nodules and reduce the false positives.
#
#
# #### Questions
# Check this values in order to determine what labels matter to know if a nodule is cancerous.

# %% [markdown]
# ![image.png](attachment:image.png)
