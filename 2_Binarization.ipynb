# %% [markdown]
# # Binary dataset

# %% [markdown]
# ### Libraries

# %%
import pandas as pd

# %% [markdown]
# ### Read Excel

# %%
df = pd.read_excel('E:/Prac_Clinicas/LIDC-IDRI/Nodules_DF_1012.xlsx', index_col=0)
df.head()
# Out:
#                 Cancer
# TCIA Patent ID
# LIDC-IDRI-0001       1
# LIDC-IDRI-0002       1
# LIDC-IDRI-0003       4
# LIDC-IDRI-0004       1
# LIDC-IDRI-0005       3

# %%
df.loc[df['Cancer'] > 1]
# Out:
#                 Cancer
# TCIA Patent ID
# LIDC-IDRI-0003       4
# LIDC-IDRI-0005       3
# LIDC-IDRI-0006       4
# LIDC-IDRI-0007       2
# LIDC-IDRI-0008       2
# ...                ...
# LIDC-IDRI-1005       7
# LIDC-IDRI-1007       2
# LIDC-IDRI-1008       6
# LIDC-IDRI-1011       4
# NaN               2669
#
# [587 rows x 1 columns]

# %% [markdown]
# ### Binarization

# %%
def Binarization (Value):
    if Value>0:
        Value = 1
    return Value

# %%
df['Cancer'] = df['Cancer'].apply(Binarization)

# %%
df.head(30)
# Out:
#                 Cancer
# TCIA Patent ID
# LIDC-IDRI-0001       1
# LIDC-IDRI-0002       1
# LIDC-IDRI-0003       1
# LIDC-IDRI-0004       1
# LIDC-IDRI-0005       1
# LIDC-IDRI-0006       1
# LIDC-IDRI-0007       1
# LIDC-IDRI-0008       1
# LIDC-IDRI-0009       1
# LIDC-IDRI-0010       1
# LIDC-IDRI-0011       1
# LIDC-IDRI-0012       1
# LIDC-IDRI-0013       1
# LIDC-IDRI-0014       1
# LIDC-IDRI-0015       1
# LIDC-IDRI-0016       1
# LIDC-IDRI-0017       1
# LIDC-IDRI-0018       1
# LIDC-IDRI-0019       1
# LIDC-IDRI-0020       1
# LIDC-IDRI-0021       1
# LIDC-IDRI-0022       1
# LIDC-IDRI-0023       1
# LIDC-IDRI-0024       1
# LIDC-IDRI-0025       1
# LIDC-IDRI-0026       1
# LIDC-IDRI-0027       1
# LIDC-IDRI-0028       0
# LIDC-IDRI-0029       1
# LIDC-IDRI-0030       1

# %% [markdown]
# ### Create Excel File

# %%
df.to_excel("E:/Prac_Clinicas/LIDC-IDRI/Nodule_Binarization.xlsx")
