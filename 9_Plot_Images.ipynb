# %% [markdown]
# ### Libraries

# %%
# %matplotlib notebook
import pickle
import matplotlib.pyplot as plt
import numpy as np
import os
import Lung_Segmentation as lung

# %% [markdown]
# ### Nodule on Original Image

# %%
# Some constants 
INPUT_FOLDER = 'F:/Prac_Clinicas/Images/LIDC-IDRI/'
patients = os.listdir(INPUT_FOLDER)
patients.sort()

# %%
patient_number = lung.load_scan(INPUT_FOLDER + patients[0])
patient_pixels = lung.get_pixels_hu(patient_number)

# %%
plt.figure()
plt.imshow(patient_pixels[44], 'gray')
# Out:
# <img src="data:image/png;base64,..." width="727.2727115095158">

# %% [markdown]
# ### Nodule on Segmented Image

# %%
pickle_in = open('F:\Prac_Clinicas\Images\Pickle\Seg_Pat_1.pickle', 'rb')
Segmented_Lung = pickle.load(pickle_in)

# %%
plt.figure()
plt.imshow(Segmented_Lung[0][44], 'gray')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
for i in range(25):
    plt.subplot(5, 5, i+1), plt.imshow(Segmented_Lung[0][i+20], 'gray')
# Out:
# <img src="data:image/png;base64,..." width="985.6">

# %% [markdown]
# ### Nodule on Resampled Image (60px)

# %%
pickle_in = open('F:\Prac_Clinicas\Images\Resampled_pickle\Patient_1.pickle', 'rb')
Image_60px = pickle.load(pickle_in)

# %%
plt.figure()
plt.imshow(Image_60px[19], 'gray')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Nodule on Resampled Image (120px)

# %%
pickle_in = open('F:\Prac_Clinicas\Images\Resampled_pickle_120\Patient_1.pickle', 'rb')
Image_120px = pickle.load(pickle_in)

# %%
plt.figure()
plt.imshow(Image_120px[38], 'gray')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
