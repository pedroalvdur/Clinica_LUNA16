# %% [markdown]
# # Segmented Images (Pickle)

# %% [markdown]
# ### Libraries

# %%
# %matplotlib notebook

import numpy as np # linear algebra
import os
import matplotlib.pyplot as plt
import pickle
import Lung_Segmentation as lung

# %% [markdown]
# ### Patients

# %%
# Some constants 
INPUT_FOLDER = 'E:/Prac_Clinicas/Images/LIDC-IDRI/'
patients = os.listdir(INPUT_FOLDER)
patients.sort()

# %%
for num, patient in enumerate(patients[-1:]):
    print(patient)
    Patient_Scan = lung.load_scan(INPUT_FOLDER + patient)
    pickle_in = open('E:\Prac_Clinicas\Images\Pickle\Seg_Pat_{}.pickle'.format(num+1), 'rb')
    Segmented_Lung = pickle.load(pickle_in)
    Segmented_patient = np.array(Segmented_Lung)
    Resampled_Lung, spacing = lung.resample(Segmented_patient[0], Patient_Scan)
    print(Resampled_Lung.shape)
    plt.figure()
    for i in range(20):
        plt.subplot(4, 5, i+1), plt.imshow(Resampled_Lung[i], 'gray')
# Out:
# (133, 512, 512)
# (66, 72, 72)
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
(np.delete(Resampled_Lung,0,2)).shape
# Out:
# (66, 72, 71)

# %%
for num, patient in enumerate(patients):
    Patient_Scan = lung.load_scan(INPUT_FOLDER + patient)
    pickle_in = open('E:\Prac_Clinicas\Images\Pickle\Seg_Pat_{}.pickle'.format(num+1), 'rb')
    Segmented_Lung = pickle.load(pickle_in)
    Segmented_patient = np.array(Segmented_Lung)
    Resampled_Lung, spacing = lung.resample(Segmented_patient[0], Patient_Scan, [5,5,5])
    print(Resampled_Lung.shape)
# Out:
# (133, 512, 512)
# (66, 72, 72)
# (261, 512, 512)
# (65, 70, 70)
# (140, 512, 512)
# (70, 84, 84)
# (241, 512, 512)
# (60, 84, 84)
# (133, 512, 512)
# (66, 68, 68)
# (133, 512, 512)
# (66, 64, 64)
# (145, 512, 512)
# (72, 80, 80)
# (133, 512, 512)
# (66, 80, 80)
# (256, 512, 512)
# (64, 80, 80)
# (277, 512, 512)
# (69, 90, 90)
# (128, 512, 512)
# (64, 76, 76)
# (128, 512, 512)
# (64, 76, 76)
# (125, 512, 512)
# (62, 60, 60)
# (114, 512, 512)
# (57, 68, 68)
# (209, 512, 512)
# (52, 71, 71)
# (141, 512, 512)
# (70, 60, 60)
# (238, 512, 512)
# (60, 75, 75)
# (127, 512, 512)
# (64, 68, 68)
# (305, 512, 512)
# (76, 83, 83)
# (225, 512, 512)
# (56, 85, 85)
# (149, 512, 512)
# (74, 76, 76)
# (133, 512, 512)
# (66, 72, 72)
# (137, 512, 512)
# (68, 76, 76)
# (133, 512, 512)
# (66, 80, 80)
# (265, 512, 512)
# (66, 97, 97)
# (257, 512, 512)
# (64, 81, 81)
# (133, 512, 512)
# (66, 88, 88)
# (141, 512, 512)
# (70, 68, 68)
# (273, 512, 512)
# (68, 90, 90)
# (119, 512, 512)
# (60, 72, 72)
# (133, 512, 512)
# (66, 88, 88)
# (249, 512, 512)
# (62, 99, 99)
# (137, 512, 512)
# (68, 80, 80)
# (265, 512, 512)
# (66, 69, 69)
# (133, 512, 512)
# (66, 84, 84)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-4b12f15736e1> in <module>
#       2     Patient_Scan = lung.load_scan(INPUT_FOLDER + patient)
#       3     pickle_in = open('E:\Prac_Clinicas\Images\Pickle\Seg_Pat_{}.pickle'.format(num+1), 'rb')
# ----> 4     Segmented_Lung = pickle.load(pickle_in)
#       5     Segmented_patient = np.array(Segmented_Lung)
#       6     Resampled_Lung, spacing = lung.resample(Segmented_patient[0], Patient_Scan, [5,5,5])
#
# KeyboardInterrupt:
